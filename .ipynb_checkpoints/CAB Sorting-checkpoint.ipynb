# %%
import os
import pandas as pd
import pypdf
import shutil

from pdf2image import convert_from_path

# %% [markdown]
# # Categorizing Docs
#
# Because we don't have any way to organize docs we're going to naively group the documents together. We only really have the doc names to try to organize things, we'll start with the largest groups and do analysis from there.
#
# Assumptions:
# - we're only interested in docs with 'cab' in the name
# - the fund name is after the 'cab' portion of the name
#
# We're narrowing down our exploration to the top 5 groups and narrowing it down to PDFs with 1 page only; we don't want to spend time categorizing what our page of interest is, although we might want to figure that out another day

# %%
sample_dir = r"C:\Users\bernard.wong\OneDrive - STEPSTONE GROUP LP\Documents\GitHub - Projects\cab_dev\sample_cabs"

sample_files = []
for filename in os.listdir(sample_dir):
    if filename.endswith(".pdf"):
        sample_files.append(filename)

# %%
summary_df = pd.DataFrame({'file_name': sample_files})
print('total number of files: ' + str(len(summary_df)))

# only want files with 'cab' in it
summary_df = summary_df[summary_df['file_name'].apply(lambda x: 'cab.' in x.lower())]
# assuming first word after cab. is the primary fund word 
summary_df['fund'] = summary_df['file_name'].apply(lambda x: x.lower().split('cab.')[1].split()[0])

grouped_fund_df = pd.DataFrame(summary_df.groupby('fund')['file_name'].apply(lambda x: list(x))).reset_index()
grouped_fund_df['num_docs'] = grouped_fund_df['file_name'].apply(lambda x: len(x))
grouped_fund_df = grouped_fund_df.sort_values('num_docs', ascending = False)
print('number of potentially different funds: ' + str(len(grouped_fund_df)))
# only want funds with more than 5 docs 
grouped_fund_df = grouped_fund_df[grouped_fund_df['num_docs'] >= 5]
print('number of interesting funds: ' + str(len(grouped_fund_df)))
print('total docs: ' + str(sum(grouped_fund_df['num_docs'])))

interest_group_df = grouped_fund_df.head(6)

interest_group_df
# Out:
# total number of files: 2056
# number of potentially different funds: 806
# number of interesting funds: 93
# total docs: 872
#             fund                                          file_name  num_docs
# 693           ss  [2021.09.30.CAB.SS A.SA.pdf, 2021.09.30.CAB.SS...        72
# 143      carlyle  [2021.09.30.CAB.Carlyle Asia Growth I.CPO III ...        30
# 673  silverstone  [2021.09.30.CAB.SilverStone Balfour.SSOF IV Of...        27
# 543          ocm  [2021.09.30.CAB.OCM Euro II USD.Sobrato FH.pdf...        24
# 94          bain  [2021.09.30.CAB.Bain Asia II.Midland.pdf, 2021...        21
# 33            ag  [2021.09.30.CAB.AG Asia Realty II.NCRS.pdf, 20...        20

# %%
# re-expanding groups to get page numbers of each file 
exploded_interest_group_df = interest_group_df.explode('file_name').reset_index(drop=True).drop(['num_docs'], axis = 1)
exploded_interest_group_df['num_pages'] = exploded_interest_group_df['file_name'].apply(lambda x: len(pypdf.PdfReader(os.path.join(sample_dir, x)).pages))
exploded_interest_group_df = exploded_interest_group_df[exploded_interest_group_df['num_pages'] == 1]
exploded_interest_group_df = pd.DataFrame(exploded_interest_group_df.groupby('fund')['file_name'].apply(lambda x: list(x))).reset_index()
exploded_interest_group_df['num_docs'] = exploded_interest_group_df['file_name'].apply(lambda x: len(x))
exploded_interest_group_df = exploded_interest_group_df.sort_values('num_docs', ascending = False)

exploded_interest_group_df
# Out:
#           fund                                          file_name  num_docs
# 4           ss  [2021.09.30.CAB.SS A.SA.pdf, 2021.09.30.CAB.SS...        71
# 3  silverstone  [2021.09.30.CAB.SilverStone Balfour.SSOF IV Of...        27
# 0           ag  [2021.09.30.CAB.AG Asia Realty II.NCRS.pdf, 20...        20
# 1         bain  [2021.09.30.CAB.Bain Asia II.Midland.pdf, 2021...        19
# 2      carlyle  [2021.09.30.CAB.Carlyle Property Investors.BMO...         1

# %% [markdown]
# # re-organizing and viewing doc differences

# %%
output_folder = 'generated_groupings'
if os.path.isdir(output_folder):
    shutil.rmtree(output_folder)
os.makedirs(output_folder)

for index, row in exploded_interest_group_df.iterrows():
    fund_folder = os.path.join(output_folder, row['fund'])
    os.makedirs(fund_folder)
    for file in row['file_name']:
        shutil.copyfile(os.path.join(sample_dir, file), os.path.join(fund_folder, file))

# %%
for fund_folder in os.listdir(output_folder):
    print(fund_folder)
    for file in os.listdir(os.path.join(output_folder, fund_folder)):
        print(' - ' + file)
        file_img = convert_from_path(os.path.join(output_folder, fund_folder, file), 500)
# Out:
# ag
#  - 2021.09.30.CAB.AG Asia Realty II.NCRS.pdf
# generated_groupings\ag\2021.09.30.CAB.AG Asia Realty II.NCRS.pdf
#  - 2021.09.30.CAB.AG Asia Realty III.Asia Realty Access Feeder.pdf
# generated_groupings\ag\2021.09.30.CAB.AG Asia Realty III.Asia Realty Access Feeder.pdf
#  - 2021.09.30.CAB.AG Asia Realty IV.LACERA.pdf
# generated_groupings\ag\2021.09.30.CAB.AG Asia Realty IV.LACERA.pdf
#  - 2021.09.30.CAB.AG Commercial RED Opps III.W VA.pdf
# generated_groupings\ag\2021.09.30.CAB.AG Commercial RED Opps III.W VA.pdf
#  - 2021.09.30.CAB.AG Commercial RED Opps.W VA.pdf
# generated_groupings\ag\2021.09.30.CAB.AG Commercial RED Opps.W VA.pdf
#  - 2021.09.30.CAB.AG Core Plus Realty II.NY Teamsters.pdf
# generated_groupings\ag\2021.09.30.CAB.AG Core Plus Realty II.NY Teamsters.pdf
#  - 2021.09.30.CAB.AG Core Plus Realty III.COH Beckman.pdf
# generated_groupings\ag\2021.09.30.CAB.AG Core Plus Realty III.COH Beckman.pdf
#  - 2021.09.30.CAB.AG Core Plus Realty IV.COH Beckman.pdf
# generated_groupings\ag\2021.09.30.CAB.AG Core Plus Realty IV.COH Beckman.pdf
#  - 2021.09.30.CAB.AG CRP VII.NYSTRS.pdf
# generated_groupings\ag\2021.09.30.CAB.AG CRP VII.NYSTRS.pdf
#  - 2021.09.30.CAB.AG Energy Credit Opps.CCCERA.pdf
# generated_groupings\ag\2021.09.30.CAB.AG Energy Credit Opps.CCCERA.pdf
#  - 2021.09.30.CAB.AG Eur Realty Holdings II.Texas Schools.pdf
# generated_groupings\ag\2021.09.30.CAB.AG Eur Realty Holdings II.Texas Schools.pdf
#  - 2021.09.30.CAB.AG Eur Realty II.LACERA.pdf
# generated_groupings\ag\2021.09.30.CAB.AG Eur Realty II.LACERA.pdf
#  - 2021.09.30.CAB.AG Eur Realty III.CIRS.pdf
# generated_groupings\ag\2021.09.30.CAB.AG Eur Realty III.CIRS.pdf
#  - 2021.09.30.CAB.AG MT Laurel Direct Lending.W VA.pdf
# generated_groupings\ag\2021.09.30.CAB.AG MT Laurel Direct Lending.W VA.pdf
#  - 2021.09.30.CAB.AG Net Lease Realty II.NCRS.pdf
# generated_groupings\ag\2021.09.30.CAB.AG Net Lease Realty II.NCRS.pdf
#  - 2021.09.30.CAB.AG Net Lease Realty III.NCRS.pdf
# generated_groupings\ag\2021.09.30.CAB.AG Net Lease Realty III.NCRS.pdf
#  - 2021.09.30.CAB.AG Net Lease Realty IV.TransGlobe Life Insurance.pdf
# generated_groupings\ag\2021.09.30.CAB.AG Net Lease Realty IV.TransGlobe Life Insurance.pdf
#  - 2021.09.30.CAB.AG Realty IX.W VA.pdf
# generated_groupings\ag\2021.09.30.CAB.AG Realty IX.W VA.pdf
#  - 2021.09.30.CAB.AG Realty VIII A.Texas Education Agency.pdf
# generated_groupings\ag\2021.09.30.CAB.AG Realty VIII A.Texas Education Agency.pdf
#  - 2021.09.30.CAB.AG Realty X.COH Beckman.pdf
# generated_groupings\ag\2021.09.30.CAB.AG Realty X.COH Beckman.pdf
# bain
#  - 2021.09.30.CAB.Bain Asia II.Midland.pdf
# generated_groupings\bain\2021.09.30.CAB.Bain Asia II.Midland.pdf
#  - 2021.09.30.CAB.Bain Distressed 2013.UCONN.pdf
# generated_groupings\bain\2021.09.30.CAB.Bain Distressed 2013.UCONN.pdf
#  - 2021.09.30.CAB.Bain Distressed 2019.Zulu Capital.pdf
# generated_groupings\bain\2021.09.30.CAB.Bain Distressed 2019.Zulu Capital.pdf
#  - 2021.09.30.CAB.Bain Europe III.GESB.pdf
# generated_groupings\bain\2021.09.30.CAB.Bain Europe III.GESB.pdf
#  - 2021.09.30.CAB.Bain Europe IV.Midland.pdf
# generated_groupings\bain\2021.09.30.CAB.Bain Europe IV.Midland.pdf
#  - 2021.09.30.CAB.Bain Europe V.Midland.pdf
# generated_groupings\bain\2021.09.30.CAB.Bain Europe V.Midland.pdf
#  - 2021.09.30.CAB.Bain IX CoInv.GESB.pdf
# generated_groupings\bain\2021.09.30.CAB.Bain IX CoInv.GESB.pdf
#  - 2021.09.30.CAB.Bain Life Sciences I.Midland.pdf
# generated_groupings\bain\2021.09.30.CAB.Bain Life Sciences I.Midland.pdf
#  - 2021.09.30.CAB.Bain Life Sciences II.Midland.pdf
# generated_groupings\bain\2021.09.30.CAB.Bain Life Sciences II.Midland.pdf
#  - 2021.09.30.CAB.Bain RE II.LACERA.pdf
# generated_groupings\bain\2021.09.30.CAB.Bain RE II.LACERA.pdf
#  - 2021.09.30.CAB.Bain Special Asia II.Zulu Capital.pdf
# generated_groupings\bain\2021.09.30.CAB.Bain Special Asia II.Zulu Capital.pdf
#  - 2021.09.30.CAB.Bain Special Asia.Midland.pdf
# generated_groupings\bain\2021.09.30.CAB.Bain Special Asia.Midland.pdf
#  - 2021.09.30.CAB.Bain Special Europe.Midland Capital.pdf
# generated_groupings\bain\2021.09.30.CAB.Bain Special Europe.Midland Capital.pdf
#  - 2021.09.30.CAB.Bain VII.Viceroy.pdf
# generated_groupings\bain\2021.09.30.CAB.Bain VII.Viceroy.pdf
#  - 2021.09.30.CAB.Bain VIII E.Midland.pdf
# generated_groupings\bain\2021.09.30.CAB.Bain VIII E.Midland.pdf
#  - 2021.09.30.CAB.Bain VIII.Viceroy.pdf
# generated_groupings\bain\2021.09.30.CAB.Bain VIII.Viceroy.pdf
#  - 2021.09.30.CAB.Bain X.Ferro.pdf
# generated_groupings\bain\2021.09.30.CAB.Bain X.Ferro.pdf
#  - 2021.09.30.CAB.Bain XII.Midland.pdf
# generated_groupings\bain\2021.09.30.CAB.Bain XII.Midland.pdf
#  - 2021.09.30.CAB.Bain XIII.Zulu.pdf
# generated_groupings\bain\2021.09.30.CAB.Bain XIII.Zulu.pdf
# carlyle
#  - 2021.09.30.CAB.Carlyle Property Investors.BMO Canada.pdf
# generated_groupings\carlyle\2021.09.30.CAB.Carlyle Property Investors.BMO Canada.pdf
# silverstone
#  - 2021.09.30.CAB.SilverStone Balfour.SSOF IV Off.pdf
# generated_groupings\silverstone\2021.09.30.CAB.SilverStone Balfour.SSOF IV Off.pdf
#  - 2021.09.30.CAB.SilverStone I.SS ATL.pdf
# generated_groupings\silverstone\2021.09.30.CAB.SilverStone I.SS ATL.pdf
#  - 2021.09.30.CAB.SilverStone II-A.SS OH.pdf
# generated_groupings\silverstone\2021.09.30.CAB.SilverStone II-A.SS OH.pdf
#  - 2021.09.30.CAB.SilverStone II-B.SSG LP.pdf
# generated_groupings\silverstone\2021.09.30.CAB.SilverStone II-B.SSG LP.pdf
#  - 2021.09.30.CAB.SilverStone II-C.AMP 3A.pdf
# generated_groupings\silverstone\2021.09.30.CAB.SilverStone II-C.AMP 3A.pdf
#  - 2021.09.30.CAB.SilverStone II-D.Montauk.pdf
# generated_groupings\silverstone\2021.09.30.CAB.SilverStone II-D.Montauk.pdf
#  - 2021.09.30.CAB.SilverStone II-E.SS UWF.pdf
# generated_groupings\silverstone\2021.09.30.CAB.SilverStone II-E.SS UWF.pdf
#  - 2021.09.30.CAB.SilverStone II-G.SS UWF.pdf
# generated_groupings\silverstone\2021.09.30.CAB.SilverStone II-G.SS UWF.pdf
#  - 2021.09.30.CAB.SilverStone II-H.SS UWF.pdf
# generated_groupings\silverstone\2021.09.30.CAB.SilverStone II-H.SS UWF.pdf
#  - 2021.09.30.CAB.SilverStone II-I.GSFA.pdf
# generated_groupings\silverstone\2021.09.30.CAB.SilverStone II-I.GSFA.pdf
#  - 2021.09.30.CAB.SilverStone II-J.SSXL A-A.pdf
# generated_groupings\silverstone\2021.09.30.CAB.SilverStone II-J.SSXL A-A.pdf
#  - 2021.09.30.CAB.SilverStone II-K Class 1.AGON.pdf
# generated_groupings\silverstone\2021.09.30.CAB.SilverStone II-K Class 1.AGON.pdf
#  - 2021.09.30.CAB.SilverStone II-K Class 2.SS UWF.pdf
# generated_groupings\silverstone\2021.09.30.CAB.SilverStone II-K Class 2.SS UWF.pdf
#  - 2021.09.30.CAB.SilverStone III Off.Viceroy.pdf
# generated_groupings\silverstone\2021.09.30.CAB.SilverStone III Off.Viceroy.pdf
#  - 2021.09.30.CAB.SilverStone IV F.SS BVK.pdf
# generated_groupings\silverstone\2021.09.30.CAB.SilverStone IV F.SS BVK.pdf
#  - 2021.09.30.CAB.SilverStone IV H.SS Ferro.pdf
# generated_groupings\silverstone\2021.09.30.CAB.SilverStone IV H.SS Ferro.pdf
#  - 2021.09.30.CAB.SilverStone IV Series B.SSOF IV Off.pdf
# generated_groupings\silverstone\2021.09.30.CAB.SilverStone IV Series B.SSOF IV Off.pdf
#  - 2021.09.30.CAB.SilverStone IV Series E.SS BVK.pdf
# generated_groupings\silverstone\2021.09.30.CAB.SilverStone IV Series E.SS BVK.pdf
#  - 2021.09.30.CAB.SilverStone IV-C.Agon.pdf
# generated_groupings\silverstone\2021.09.30.CAB.SilverStone IV-C.Agon.pdf
#  - 2021.09.30.CAB.SilverStone IV-D.SS Partners LP.pdf
# generated_groupings\silverstone\2021.09.30.CAB.SilverStone IV-D.SS Partners LP.pdf
#  - 2021.09.30.CAB.SilverStone IV-I.SS TS.pdf
# generated_groupings\silverstone\2021.09.30.CAB.SilverStone IV-I.SS TS.pdf
#  - 2021.09.30.CAB.SilverStone IV-J.SSOF IV Euro.pdf
# generated_groupings\silverstone\2021.09.30.CAB.SilverStone IV-J.SSOF IV Euro.pdf
#  - 2021.09.30.CAB.SilverStone IV-K.SSOF IV Off.pdf
# generated_groupings\silverstone\2021.09.30.CAB.SilverStone IV-K.SSOF IV Off.pdf
#  - 2021.09.30.CAB.Silverstone IV-L.SSOF IV Euro.pdf
# generated_groupings\silverstone\2021.09.30.CAB.Silverstone IV-L.SSOF IV Euro.pdf
#  - 2021.09.30.CAB.SilverStone IV.SS BVK.pdf
# generated_groupings\silverstone\2021.09.30.CAB.SilverStone IV.SS BVK.pdf
#  - 2021.09.30.CAB.SilverStone Pattern A.SS TS.pdf
# generated_groupings\silverstone\2021.09.30.CAB.SilverStone Pattern A.SS TS.pdf
#  - 2021.09.30.CAB.SilverStone Pebbles IV.SSOF IV.pdf
# generated_groupings\silverstone\2021.09.30.CAB.SilverStone Pebbles IV.SSOF IV.pdf
# ss
#  - 2021.09.30.CAB.SS A.SA.pdf
# generated_groupings\ss\2021.09.30.CAB.SS A.SA.pdf
#  - 2021.09.30.CAB.SS Aegon A.TransAmerica.pdf
# generated_groupings\ss\2021.09.30.CAB.SS Aegon A.TransAmerica.pdf
#  - 2021.09.30.CAB.SS AP B.Farley I.pdf
# generated_groupings\ss\2021.09.30.CAB.SS AP B.Farley I.pdf
#  - 2021.09.30.CAB.SS AP.Farley II.pdf
# generated_groupings\ss\2021.09.30.CAB.SS AP.Farley II.pdf
#  - 2021.09.30.CAB.SS AZ China II.AZPSPRS.pdf
# generated_groupings\ss\2021.09.30.CAB.SS AZ China II.AZPSPRS.pdf
#  - 2021.09.30.CAB.SS AZ China.SS Partners Carry.pdf
# generated_groupings\ss\2021.09.30.CAB.SS AZ China.SS Partners Carry.pdf
#  - 2021.09.30.CAB.SS BVK II.SS Partners.pdf
# generated_groupings\ss\2021.09.30.CAB.SS BVK II.SS Partners.pdf
#  - 2021.09.30.CAB.SS BVK.SS Partners.pdf
# generated_groupings\ss\2021.09.30.CAB.SS BVK.SS Partners.pdf
#  - 2021.09.30.CAB.SS C Strategic Core Infra.CALSTRS.pdf
# generated_groupings\ss\2021.09.30.CAB.SS C Strategic Core Infra.CALSTRS.pdf
#  - 2021.09.30.CAB.SS E Off.SS Partners.pdf
# generated_groupings\ss\2021.09.30.CAB.SS E Off.SS Partners.pdf
#  - 2021.09.30.CAB.SS E.Enstar.pdf
# generated_groupings\ss\2021.09.30.CAB.SS E.Enstar.pdf
#  - 2021.09.30.CAB.SS Endurance.UConn.pdf
# generated_groupings\ss\2021.09.30.CAB.SS Endurance.UConn.pdf
#  - 2021.09.30.CAB.SS ET Strategic.OHPERS.pdf
# generated_groupings\ss\2021.09.30.CAB.SS ET Strategic.OHPERS.pdf
#  - 2021.09.30.CAB.SS Euro SCS SREP III.SS GP.pdf
# generated_groupings\ss\2021.09.30.CAB.SS Euro SCS SREP III.SS GP.pdf
#  - 2021.09.30.CAB.SS Ferro Holdgs.Ferro.pdf
# generated_groupings\ss\2021.09.30.CAB.SS Ferro Holdgs.Ferro.pdf
#  - 2021.09.30.CAB.SS FSS.SSG.pdf
# generated_groupings\ss\2021.09.30.CAB.SS FSS.SSG.pdf
#  - 2021.09.30.CAB.SS G Infra.GPIF.PE.pdf
# generated_groupings\ss\2021.09.30.CAB.SS G Infra.GPIF.PE.pdf
#  - 2021.09.30.CAB.SS H.SS Partners Carry.pdf
# generated_groupings\ss\2021.09.30.CAB.SS H.SS Partners Carry.pdf
#  - 2021.09.30.CAB.SS JP Opps IA.SS JP GP.pdf
# generated_groupings\ss\2021.09.30.CAB.SS JP Opps IA.SS JP GP.pdf
#  - 2021.09.30.CAB.SS JP Opps.SS JP GP.pdf
# generated_groupings\ss\2021.09.30.CAB.SS JP Opps.SS JP GP.pdf
#  - 2021.09.30.CAB.SS K Infra.KIA.pdf
# generated_groupings\ss\2021.09.30.CAB.SS K Infra.KIA.pdf
#  - 2021.09.30.CAB.SS KF Infra Holdgs.SS KF GP.pdf
# generated_groupings\ss\2021.09.30.CAB.SS KF Infra Holdgs.SS KF GP.pdf
#  - 2021.09.30.CAB.SS KF Infra Holdings II.SS KF GP.pdf
# generated_groupings\ss\2021.09.30.CAB.SS KF Infra Holdings II.SS KF GP.pdf
#  - 2021.09.30.CAB.SS KF Infra II.SS KF GP.pdf
# generated_groupings\ss\2021.09.30.CAB.SS KF Infra II.SS KF GP.pdf
#  - 2021.09.30.CAB.SS KF Infra.SS KF GP.pdf
# generated_groupings\ss\2021.09.30.CAB.SS KF Infra.SS KF GP.pdf
#  - 2021.09.30.CAB.SS KF PE Holdgs.KFAED PE.pdf
# generated_groupings\ss\2021.09.30.CAB.SS KF PE Holdgs.KFAED PE.pdf
#  - 2021.09.30.CAB.SS KF PE II Holdgs.SS KF GP.pdf
# generated_groupings\ss\2021.09.30.CAB.SS KF PE II Holdgs.SS KF GP.pdf
#  - 2021.09.30.CAB.SS KF PE II.SS Partners Carry.pdf
# generated_groupings\ss\2021.09.30.CAB.SS KF PE II.SS Partners Carry.pdf
#  - 2021.09.30.CAB.SS KF PE.SS KF GP.pdf
# generated_groupings\ss\2021.09.30.CAB.SS KF PE.SS KF GP.pdf
#  - 2021.09.30.CAB.SS LMM Opps A.Ford.pdf
# generated_groupings\ss\2021.09.30.CAB.SS LMM Opps A.Ford.pdf
#  - 2021.09.30.CAB.SS LMM Opps B.Ford.pdf
# generated_groupings\ss\2021.09.30.CAB.SS LMM Opps B.Ford.pdf
#  - 2021.09.30.CAB.SS Maple Feeder.GCUT CI.pdf
# generated_groupings\ss\2021.09.30.CAB.SS Maple Feeder.GCUT CI.pdf
#  - 2021.09.30.CAB.SS Mexico A2.SS Mexico.pdf
# generated_groupings\ss\2021.09.30.CAB.SS Mexico A2.SS Mexico.pdf
#  - 2021.09.30.CAB.SS Mexico B2.SS Mexico.pdf
# generated_groupings\ss\2021.09.30.CAB.SS Mexico B2.SS Mexico.pdf
#  - 2021.09.30.CAB.SS Mexico C2.SS Mexico.pdf
# generated_groupings\ss\2021.09.30.CAB.SS Mexico C2.SS Mexico.pdf
#  - 2021.09.30.CAB.SS Mexico CoInv.SS Mexico I SPC.pdf
# generated_groupings\ss\2021.09.30.CAB.SS Mexico CoInv.SS Mexico I SPC.pdf
#  - 2021.09.30.CAB.SS Mexico D2.SS Mexico.pdf
# generated_groupings\ss\2021.09.30.CAB.SS Mexico D2.SS Mexico.pdf
#  - 2021.09.30.CAB.SS NL Opps II.SS NL GP.pdf
# generated_groupings\ss\2021.09.30.CAB.SS NL Opps II.SS NL GP.pdf
#  - 2021.09.30.CAB.SS NL Opps III.CoInv III Ltd.pdf
# generated_groupings\ss\2021.09.30.CAB.SS NL Opps III.CoInv III Ltd.pdf
#  - 2021.09.30.CAB.SS NL Opps.SS NL GP.pdf
# generated_groupings\ss\2021.09.30.CAB.SS NL Opps.SS NL GP.pdf
#  - 2021.09.30.CAB.SS NLGI Infra Opps.SS NLGI GP.pdf
# generated_groupings\ss\2021.09.30.CAB.SS NLGI Infra Opps.SS NLGI GP.pdf
#  - 2021.09.30.CAB.SS NPS Infra I.SS Partners Carry.pdf
# generated_groupings\ss\2021.09.30.CAB.SS NPS Infra I.SS Partners Carry.pdf
#  - 2021.09.30.CAB.SS NPS Infra II.SS NPS GP.pdf
# generated_groupings\ss\2021.09.30.CAB.SS NPS Infra II.SS NPS GP.pdf
#  - 2021.09.30.CAB.SS NPS PE B.NPS.pdf
# generated_groupings\ss\2021.09.30.CAB.SS NPS PE B.NPS.pdf
#  - 2021.09.30.CAB.SS NPS PE II A.SS Partners.pdf
# generated_groupings\ss\2021.09.30.CAB.SS NPS PE II A.SS Partners.pdf
#  - 2021.09.30.CAB.SS P Infra.PIFSS.pdf
# generated_groupings\ss\2021.09.30.CAB.SS P Infra.PIFSS.pdf
#  - 2021.09.30.CAB.SS P.PIFSS.pdf
# generated_groupings\ss\2021.09.30.CAB.SS P.PIFSS.pdf
#  - 2021.09.30.CAB.SS Phoenix B.Nostro.pdf
# generated_groupings\ss\2021.09.30.CAB.SS Phoenix B.Nostro.pdf
#  - 2021.09.30.CAB.SS Phoenix Infra Debt.SS Partners.pdf
# generated_groupings\ss\2021.09.30.CAB.SS Phoenix Infra Debt.SS Partners.pdf
#  - 2021.09.30.CAB.SS Phoenix Infra Equity.SS Partners.pdf
# generated_groupings\ss\2021.09.30.CAB.SS Phoenix Infra Equity.SS Partners.pdf
#  - 2021.09.30.CAB.SS PIFSS.PISSK.pdf
# generated_groupings\ss\2021.09.30.CAB.SS PIFSS.PISSK.pdf
#  - 2021.09.30.CAB.SS PTS Infra Holdings.SS Partners.pdf
# generated_groupings\ss\2021.09.30.CAB.SS PTS Infra Holdings.SS Partners.pdf
#  - 2021.09.30.CAB.SS R CoInv Class B.SS Partners LP.pdf
# generated_groupings\ss\2021.09.30.CAB.SS R CoInv Class B.SS Partners LP.pdf
#  - 2021.09.30.CAB.SS RE Euo CoInv Holdings.SS Partners.pdf
# generated_groupings\ss\2021.09.30.CAB.SS RE Euo CoInv Holdings.SS Partners.pdf
#  - 2021.09.30.CAB.SS RE Euro CoInv.NPS.pdf
# generated_groupings\ss\2021.09.30.CAB.SS RE Euro CoInv.NPS.pdf
#  - 2021.09.30.CAB.SS Rivas Holdgs.Macro.pdf
# generated_groupings\ss\2021.09.30.CAB.SS Rivas Holdgs.Macro.pdf
#  - 2021.09.30.CAB.SS Rivas PE.SS Partners Carry.pdf
# generated_groupings\ss\2021.09.30.CAB.SS Rivas PE.SS Partners Carry.pdf
#  - 2021.09.30.CAB.SS Scorpio Infra B.Prudential.pdf
# generated_groupings\ss\2021.09.30.CAB.SS Scorpio Infra B.Prudential.pdf
#  - 2021.09.30.CAB.SS SECDO US.SS SEDCO GP.pdf
# generated_groupings\ss\2021.09.30.CAB.SS SECDO US.SS SEDCO GP.pdf
#  - 2021.09.30.CAB.SS Tactical II Off Holdgs.SS Partners Carry.pdf
# generated_groupings\ss\2021.09.30.CAB.SS Tactical II Off Holdgs.SS Partners Carry.pdf
#  - 2021.09.30.CAB.SS Tactical II Off.SS Mexico.pdf
# generated_groupings\ss\2021.09.30.CAB.SS Tactical II Off.SS Mexico.pdf
#  - 2021.09.30.CAB.SS Tactical II.SS ATL.pdf
# generated_groupings\ss\2021.09.30.CAB.SS Tactical II.SS ATL.pdf
#  - 2021.09.30.CAB.SS Tactical III.SS Rivas.pdf
# generated_groupings\ss\2021.09.30.CAB.SS Tactical III.SS Rivas.pdf
#  - 2021.09.30.CAB.SS Tactical Off Holdgs.SS Partners Carry.pdf
# generated_groupings\ss\2021.09.30.CAB.SS Tactical Off Holdgs.SS Partners Carry.pdf
#  - 2021.09.30.CAB.SS Tactical Off.SS Partners.pdf
# generated_groupings\ss\2021.09.30.CAB.SS Tactical Off.SS Partners.pdf
#  - 2021.09.30.CAB.SS Tactical.SS ATL 2014.pdf
# generated_groupings\ss\2021.09.30.CAB.SS Tactical.SS ATL 2014.pdf
#  - 2021.09.30.CAB.SS TS Opps.SS TS GP.pdf
# generated_groupings\ss\2021.09.30.CAB.SS TS Opps.SS TS GP.pdf
#  - 2021.09.30.CAB.SS VMB Holdings.SS Partners Carry.pdf
# generated_groupings\ss\2021.09.30.CAB.SS VMB Holdings.SS Partners Carry.pdf
#  - 2021.09.30.CAB.SS VMB SOF.Multibrand.pdf
# generated_groupings\ss\2021.09.30.CAB.SS VMB SOF.Multibrand.pdf
#  - 2021.09.30.CAB.SS Waterfall Agg.SSXL II-A Series C.pdf
# generated_groupings\ss\2021.09.30.CAB.SS Waterfall Agg.SSXL II-A Series C.pdf
#  - 2021.09.30.CAB.SS Yellowcreek.SS Partners Carry.pdf
# generated_groupings\ss\2021.09.30.CAB.SS Yellowcreek.SS Partners Carry.pdf
